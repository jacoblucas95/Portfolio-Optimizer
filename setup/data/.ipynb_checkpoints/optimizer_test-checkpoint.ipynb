# %%
import json, requests
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
etf_list = ['VTI','VEA', 'VWO', 'VNQ', 'XLE', 'BND', 'SCHP', 'VTEB', 'VIG']
pickle_list = []
for etf in etf_list:
    pickle_name = etf + '.pickle'
    pickle_list.append(pickle_name)

# %%
df_list = []
for etf in pickle_list:
    df_name = 'df_' + etf[0:2]
    df_name = pd.read_pickle(etf)
    df_list.append(df_name)

# %%
for df in df_list:
    df['Normed Return'] = df['close'] / df.iloc[0]['close']
    df['Allocation'] = df['Normed Return'] * (1/9)
    df['Pos'] = df['Allocation'] * 100000

# %%
pos_ls = []
for df in df_list:
    pos_ls.append(df['Pos'])

# %%
portfolio_val = pd.concat(pos_ls, axis=1)

# %%
portfolio_val.columns = ['vti pos', 'vea pos', 'vwo pos', 'vnq pos', 'xle pos', 'bnd pos', 'schp pos', 'vteb pos', 'vig pos']

# %%
portfolio_val['Total Pos'] = portfolio_val.sum(axis = 1)

# %%
portfolio_val['Daily Return'] = portfolio_val['Total Pos'].pct_change(1)

# %%
SR = portfolio_val['Daily Return'].mean()/portfolio_val['Daily Return'].std()

# %%
ASR = (252**0.5) * SR
ASR
# Out:
# 0.2728004602156196

# %%
close_ls = []
for df in df_list:
    close_ls.append(df['close'])
stocks = pd.concat(close_ls,axis=1)
stocks.columns = ['VTI','VEA', 'VWO', 'VNQ', 'XLE', 'BND', 'SCHP', 'VTEB', 'VIG']

# %%
stocks.head()
# Out:
#       VTI    VEA    VWO    VNQ    XLE    BND   SCHP   VTEB    VIG
# 0  124.93  41.94  41.20  82.71  65.98  82.10  55.72  51.63  93.39
# 1  125.07  41.91  41.17  83.29  65.05  81.99  55.53  51.59  93.52
# 2  125.29  41.85  41.25  83.09  64.86  81.93  55.52  51.53  93.57
# 3  125.19  41.70  40.97  83.67  66.42  81.86  55.43  51.47  93.75
# 4  125.17  41.57  40.82  84.42  66.89  81.84  55.36  51.43  93.82

# %%
mean_daily_return = stocks.pct_change(1).mean()
mean_daily_return
# Out:
# VTI     0.000341
# VEA    -0.000031
# VWO     0.000028
# VNQ     0.000178
# XLE    -0.000083
# BND     0.000002
# SCHP    0.000009
# VTEB    0.000048
# VIG     0.000407
# dtype: float64

# %%
stocks.pct_change(1).corr()
# Out:
#            VTI       VEA       VWO       VNQ       XLE       BND      SCHP  \
# VTI   1.000000  0.846268  0.733550  0.504939  0.695658 -0.228488 -0.205716
# VEA   0.846268  1.000000  0.829175  0.387538  0.673845 -0.201675 -0.162256
# VWO   0.733550  0.829175  1.000000  0.337339  0.540985 -0.117585 -0.092313
# VNQ   0.504939  0.387538  0.337339  1.000000  0.253555  0.165349  0.131203
# XLE   0.695658  0.673845  0.540985  0.253555  1.000000 -0.215633 -0.098765
# BND  -0.228488 -0.201675 -0.117585  0.165349 -0.215633  1.000000  0.828045
# SCHP -0.205716 -0.162256 -0.092313  0.131203 -0.098765  0.828045  1.000000
# VTEB -0.211033 -0.218785 -0.141221  0.142251 -0.208709  0.715790  0.621746
# VIG   0.949317  0.798190  0.678512  0.534028  0.634595 -0.194156 -0.182597
#
#           VTEB       VIG
# VTI  -0.211033  0.949317
# VEA  -0.218785  0.798190
# VWO  -0.141221  0.678512
# VNQ   0.142251  0.534028
# XLE  -0.208709  0.634595
# BND   0.715790 -0.194156
# SCHP  0.621746 -0.182597
# VTEB  1.000000 -0.175309
# VIG  -0.175309  1.000000

# %%
stock_normed = stocks/stocks.iloc[0]
stock_normed.plot()

# %%
stock_daily_return = stocks.pct_change(1)
stock_daily_return.head()
# Out:
#         VTI       VEA       VWO       VNQ       XLE       BND      SCHP  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1  0.001121 -0.000715 -0.000728  0.007012 -0.014095 -0.001340 -0.003410
# 2  0.001759 -0.001432  0.001943 -0.002401 -0.002921 -0.000732 -0.000180
# 3 -0.000798 -0.003584 -0.006788  0.006980  0.024052 -0.000854 -0.001621
# 4 -0.000160 -0.003118 -0.003661  0.008964  0.007076 -0.000244 -0.001263
#
#        VTEB       VIG
# 0       NaN       NaN
# 1 -0.000775  0.001392
# 2 -0.001163  0.000535
# 3 -0.001164  0.001924
# 4 -0.000777  0.000747

# %%
log_ret = np.log(stocks/stocks.shift(1))
pickle_path = os.path.join(os.path.join(os.path.dirname(os.getcwd()), 'data', 'log_ret.pickle'))
log_ret.to_pickle(pickle_path)
log_ret.head()
# Out:
#         VTI       VEA       VWO       VNQ       XLE       BND      SCHP  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1  0.001120 -0.000716 -0.000728  0.006988 -0.014195 -0.001341 -0.003416
# 2  0.001757 -0.001433  0.001941 -0.002404 -0.002925 -0.000732 -0.000180
# 3 -0.000798 -0.003591 -0.006811  0.006956  0.023767 -0.000855 -0.001622
# 4 -0.000160 -0.003122 -0.003668  0.008924  0.007051 -0.000244 -0.001264
#
#        VTEB       VIG
# 0       NaN       NaN
# 1 -0.000775  0.001391
# 2 -0.001164  0.000535
# 3 -0.001165  0.001922
# 4 -0.000777  0.000746

# %%
log_ret.hist(bins=100,figsize=(12,6));
plt.tight_layout()

# %%
log_ret.describe().transpose()
# Out:
#       count          mean       std       min       25%       50%       75%  \
# VTI   503.0  3.026169e-04  0.008806 -0.040144 -0.002614  0.000622  0.004865
# VEA   503.0 -6.113182e-05  0.007733 -0.041645 -0.004082  0.000714  0.004476
# VWO   503.0 -3.014497e-05  0.010781 -0.034406 -0.006660  0.001133  0.007082
# VNQ   503.0  1.387806e-04  0.008823 -0.038392 -0.004147  0.000714  0.005684
# XLE   503.0 -1.563454e-04  0.012128 -0.042860 -0.006043  0.000479  0.006579
# BND   503.0  4.842459e-07  0.001758 -0.006426 -0.001112  0.000122  0.001096
# SCHP  503.0  7.123159e-06  0.002026 -0.006232 -0.001303  0.000000  0.001292
# VTEB  503.0  4.755924e-05  0.001345 -0.006575 -0.000593  0.000192  0.000962
# VIG   503.0  3.740012e-04  0.008162 -0.040580 -0.003220  0.001144  0.004438
#
#            max
# VTI   0.046998
# VEA   0.030285
# VWO   0.035292
# VNQ   0.032907
# XLE   0.060362
# BND   0.006927
# SCHP  0.006773
# VTEB  0.004247
# VIG   0.040440

# %%
log_ret.mean() * 252
# Out:
# VTI     0.076259
# VEA    -0.015405
# VWO    -0.007597
# VNQ     0.034973
# XLE    -0.039399
# BND     0.000122
# SCHP    0.001795
# VTEB    0.011985
# VIG     0.094248
# dtype: float64

# %%
log_ret.cov() * 252
# Out:
#            VTI       VEA       VWO       VNQ       XLE       BND      SCHP  \
# VTI   0.019540  0.014532  0.017560  0.009894  0.018727 -0.000891 -0.000926
# VEA   0.014532  0.015070  0.017429  0.006679  0.015956 -0.000691 -0.000641
# VWO   0.017560  0.017429  0.029292  0.008102  0.017870 -0.000562 -0.000508
# VNQ   0.009894  0.006679  0.008102  0.019618  0.006851  0.000648  0.000590
# XLE   0.018727  0.015956  0.017870  0.006851  0.037069 -0.001156 -0.000612
# BND  -0.000891 -0.000691 -0.000562  0.000648 -0.001156  0.000779  0.000744
# SCHP -0.000926 -0.000641 -0.000508  0.000590 -0.000612  0.000744  0.001035
# VTEB -0.000629 -0.000573 -0.000515  0.000427 -0.000856  0.000427  0.000427
# VIG   0.017198  0.012707  0.015056  0.009703  0.015842 -0.000701 -0.000761
#
#           VTEB       VIG
# VTI  -0.000629  0.017198
# VEA  -0.000573  0.012707
# VWO  -0.000515  0.015056
# VNQ   0.000427  0.009703
# XLE  -0.000856  0.015842
# BND   0.000427 -0.000701
# SCHP  0.000427 -0.000761
# VTEB  0.000456 -0.000484
# VIG  -0.000484  0.016789

# %%
num_ports = 1000
all_weights = np.zeros((num_ports, len(stocks.columns)))
ret_arr = np.zeros(num_ports)
vol_arr = np.zeros(num_ports)
sharpe_arr = np.zeros(num_ports)

for ind in range(num_ports):
    weights = np.array(np.random.random(9))
    weights = weights / np.sum(weights)
    all_weights[ind, :] = weights
    
    ret_arr[ind] = np.sum((log_ret.mean()*weights)*252)
    vol_arr[ind] = np.sqrt(np.dot(weights.T,np.dot(log_ret.cov()*252,weights)))
    sharpe_arr[ind] = ret_arr[ind]/vol_arr[ind]

# %%
m = sharpe_arr.argmax()
all_weights[m,:]
sharpe_arr.max()
# Out:
# 0.5745161682056864

# %%
max_sr_ret = ret_arr[m]
max_sr_vol = vol_arr[m]

# %%
plt.figure(figsize=(12,8))
plt.scatter(vol_arr,ret_arr,c=sharpe_arr,cmap='plasma')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')
# Out:
# Text(0, 0.5, 'Return')
